# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\aluca\.virtualenvs\spotify-light-show-okfwy01m\lib\site-packages (2.28.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\aluca\.virtualenvs\spotify-light-show-okfwy01m\lib\site-packages (from requests) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aluca\.virtualenvs\spotify-light-show-okfwy01m\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aluca\.virtualenvs\spotify-light-show-okfwy01m\lib\site-packages (from requests) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aluca\.virtualenvs\spotify-light-show-okfwy01m\lib\site-packages (from requests) (3.0.1)

# %%
import requests
import datetime
import base64
from urllib.parse import urlencode

# %%
client_id = "11ff7112cf044de8bb8626fb93505bbc"
client_secret = "551ab8978f3d4ea5a1c57ce762373ae7"

# %%
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url = "https://accounts.spotify.com/api/token"
    base_url = "https://api.spotify.com/v1"
    method = "POST"
    
    
    def __init__(self,client_id,client_secret,*args, **kwargs):
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret =client_secret
        
    def get_client_credentials(self):
        """"""
        "Returns a base64 encoded string"
        """"""
        client_id = self.client_id
        client_secret = self.client_secret
        if client_secret == None or client_id == None:
            raise Exemption("You must set client_id and client_secret")
        client_creds = f"{client_id}:{client_secret}" #Client details as string
        client_creds_b64 =base64.b64encode(client_creds.encode()) #Turn string into base64 type
        return client_creds_b64.decode() #Return as decoded base64 string
        
    def get_token_headers(self):
        
        client_creds_b64 = self.get_client_credentials() #get decoded client credentials.
        return {
            "Authorization" : f"Basic {client_creds_b64}" 
        }
    def get_token_data(self):
        return {
            "grant_type":"client_credentials"
        }
    
    def perform_auth(self):
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_headers()
        r = requests.post(token_url, data=token_data, headers=token_headers)
        if r.status_code not in range(200,299):
            raise Exception("Could not authenticate client")
            #return False
        data = r.json()
        now = datetime.datetime.now()
        access_token = data['access_token']
        self.access_token = access_token
        expires_in = data['expires_in'] #in seconds
        token_type = data['token_type'] 
        expires = now + datetime.timedelta(seconds=expires_in)
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        return True
        
    def get_access_token(self):
        token = self.access_token
        expires = self.access_token_expires
        now = datetime.datetime.now()
        if expires < now:
            self.perform_auth()
            return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token()
        return token
    
    def get_resource_headers(self):
        access_token = self.get_access_token()
        headers = {
            "Authorization" : f"Bearer {access_token}"
        }
        return headers
    
    def get_id(self,):
        pass
    
    def get_resource(self, lookup_id, resource_type='albums',version='v1'):
        endpoint = f"https://api.spotify.com/{version}/{resource_type}/{lookup_id}"
        headers = self.get_resource_headers()
        r = requests.get(endpoint, headers = headers)
        if r.status_code not in range(200,299):
            return {}
        return r.json()
        
    def get_album(self, _id):
        return self.get_resource(_id, resource_type='albums')
    
    def get_artist(self, _id):
        return self.get_resource(_id, resource_type='artists')
    
    def get_track(self,):
        pass
    def get_track_features(self,):
        pass
    def get_audio_analysis(self,):
        pass
        
    def search(self, query, search_type='artist'): #type is a built-in python operator
        headers = self.get_resource_headers()
        endpoint = "https://api.spotify.com/v1/search"
        data = urlencode({"q": query, "type": search_type.lower()})
        lookup_url = f"{endpoint}?{data}"
        print(lookup_url)
        r = requests.get(lookup_url, headers=headers)
        print(r.status_code)
        if r.status_code not in range(200,299):
            return {}
        return r.json()

# %%
spotify = SpotifyAPI(client_id,client_secret)

# %%
spotify.search("Luv me a little", search_type="track")
# Out:
# https://api.spotify.com/v1/search?q=Luv+me+a+little&type=track
# 200
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Luv+me+a+little&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/45eNHdiiabvmbp4erw26rg'},
#        'href': 'https://api.spotify.com/v1/artists/45eNHdiiabvmbp4erw26rg',
#        'id': '45eNHdiiabvmbp4erw26rg',
#        'name': 'ILLENIUM',
#        'type': 'artist',
#        'uri': 'spotify:artist:45eNHdiiabvmbp4erw26rg'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/7AzjETXRUKNRSJHMW9GIqd'},
#        'href': 'https://api.spotify.com/v1/artists/7AzjETXRUKNRSJHMW9GIqd',
#        'id': '7AzjETXRUKNRSJHMW9GIqd',
#        'name': 'Nina Nesbitt',
#        'type': 'artist',
#        'uri': 'spotify:artist:7AzjETXRUKNRSJHMW9GIqd'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7rZOkDS1qDISQN3kValLId'},
#      'href': 'https://api.spotify.com/v1/albums/7rZOkDS1qDISQN3kValLId',
#      'id': '7rZOkDS1qDISQN3kValLId',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732c63e6bc06a8b23366662cd5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022c63e6bc06a8b23366662cd5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512c63e6bc06a8b23366662cd5',
#        'width': 64}],
#      'name': 'Luv Me A Little',
#      'release_date': '2023-01-20',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:7rZOkDS1qDISQN3kValLId'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/45eNHdiiabvmbp4erw26rg'},
#       'href': 'https://api.spotify.com/v1/artists/45eNHdiiabvmbp4erw26rg',
#       'id': '45eNHdiiabvmbp4erw26rg',
#       'name': 'ILLENIUM',
#       'type': 'artist',
#       'uri': 'spotify:artist:45eNHdiiabvmbp4erw26rg'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7AzjETXRUKNRSJHMW9GIqd'},
#       'href': 'https://api.spotify.com/v1/artists/7AzjETXRUKNRSJHMW9GIqd',
#       'id': '7AzjETXRUKNRSJHMW9GIqd',
#       'name': 'Nina Nesbitt',
#       'type': 'artist',
#       'uri': 'spotify:artist:7AzjETXRUKNRSJHMW9GIqd'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 224615,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB12207330'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1SFA5zEVOsLhEg7ynbvQFT'},
#     'href': 'https://api.spotify.com/v1/tracks/1SFA5zEVOsLhEg7ynbvQFT',
#     'id': '1SFA5zEVOsLhEg7ynbvQFT',
#     'is_local': False,
#     'name': 'Luv Me A Little',
#     'popularity': 69,
#     'preview_url': 'https://p.scdn.co/mp3-preview/069369eaa1075368692d474436f6a3b84988912d?cid=11ff7112cf044de8bb8626fb93505bbc',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1SFA5zEVOsLhEg7ynbvQFT'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BG',
#       'BH',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BZ',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DM',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GB',
#       'GD',
#       'GE',
#       'GR',
#       'GT',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KG',
#       'KH',
#       'KI',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MD',
#       'ME',
#       'MH',
#       'MK',
#       'MN',
#       'MO',
#       'MT',
#       'MV',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'SA',
#       'SB',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SM',
#       'SR',
#       'SV',
#       'TH',
#       'TJ',
#       'TL',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/75e6Bqjk892UUJdyyY03Fo'},
#      'href': 'https://api.spotify.com/v1/albums/75e6Bqjk892UUJdyyY03Fo',
#      'id': '75e6Bqjk892UUJdyyY03Fo',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27313175c8c8110c2d084411562',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0213175c8c8110c2d084411562',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485113175c8c8110c2d084411562',
#        'width': 64}],
#      'name': "20's Love Songs",
#      'release_date': '2023-02-20',
#      'release_date_precision': 'day',
#      'total_tracks': 35,
#      'type': 'album',
#      'uri': 'spotify:album:75e6Bqjk892UUJdyyY03Fo'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/45eNHdiiabvmbp4erw26rg'},
#       'href': 'https://api.spotify.com/v1/artists/45eNHdiiabvmbp4erw26rg',
#       'id': '45eNHdiiabvmbp4erw26rg',
#       'name': 'ILLENIUM',
#       'type': 'artist',
#       'uri': 'spotify:artist:45eNHdiiabvmbp4erw26rg'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7AzjETXRUKNRSJHMW9GIqd'},
#       'href': 'https://api.spotify.com/v1/artists/7AzjETXRUKNRSJHMW9GIqd',
#       'id': '7AzjETXRUKNRSJHMW9GIqd',
#       'name': 'Nina Nesbitt',
#       'type': 'artist',
#       'uri': 'spotify:artist:7AzjETXRUKNRSJHMW9GIqd'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'CW',
#      'DM',
#      'FJ',
#      'GE',
#      'GD',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'MV',
#      'MH',
#      'FM',
#      'NR',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'KH',
#      'KG',
#      'LA',
#      'MO',
#      'MN',
#      'NP',
#      'UZ',
#      'IQ',
#      'TJ',
#      'VE',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 224615,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB12207330'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0GJAlocJ1B4N3uFAXXuByl'},
#     'href': 'https://api.spotify.com/v1/tracks/0GJAlocJ1B4N3uFAXXuByl',
#     'id': '0GJAlocJ1B4N3uFAXXuByl',
#     'is_local': False,
#     'name': 'Luv Me a Little',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/069369eaa1075368692d474436f6a3b84988912d?cid=11ff7112cf044de8bb8626fb93505bbc',
#     'track_number': 20,
#     'type': 'track',
#     'uri': 'spotify:track:0GJAlocJ1B4N3uFAXXuByl'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/45eNHdiiabvmbp4erw26rg'},
#        'href': 'https://api.spotify.com/v1/artists/45eNHdiiabvmbp4erw26rg',
#        'id': '45eNHdiiabvmbp4erw26rg',
#        'name': 'ILLENIUM',
#        'type': 'artist',
#        'uri': 'spotify:artist:45eNHdiiabvmbp4erw26rg'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/7AzjETXRUKNRSJHMW9GIqd'},
#        'href': 'https://api.spotify.com/v1/artists/7AzjETXRUKNRSJHMW9GIqd',
#        'id': '7AzjETXRUKNRSJHMW9GIqd',
#        'name': 'Nina Nesbitt',
#        'type': 'artist',
#        'uri': 'spotify:artist:7AzjETXRUKNRSJHMW9GIqd'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Wg2b4Mp42gicxEeDNawf7'},
#        'href': 'https://api.spotify.com/v1/artists/5Wg2b4Mp42gicxEeDNawf7',
#        'id': '5Wg2b4Mp42gicxEeDNawf7',
#        'name': 'A7S',
#        'type': 'artist',
#        'uri': 'spotify:artist:5Wg2b4Mp42gicxEeDNawf7'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4wLCDwwF2uaKj1susQ0yHt'},
#      'href': 'https://api.spotify.com/v1/albums/4wLCDwwF2uaKj1susQ0yHt',
#      'id': '4wLCDwwF2uaKj1susQ0yHt',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739d7d8a040b9818d79b3c4454',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029d7d8a040b9818d79b3c4454',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519d7d8a040b9818d79b3c4454',
#        'width': 64}],
#      'name': 'Luv Me A Little (A7S DnB Remix)',
#      'release_date': '2023-02-17',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:4wLCDwwF2uaKj1susQ0yHt'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/45eNHdiiabvmbp4erw26rg'},
#       'href': 'https://api.spotify.com/v1/artists/45eNHdiiabvmbp4erw26rg',
#       'id': '45eNHdiiabvmbp4erw26rg',
#       'name': 'ILLENIUM',
#       'type': 'artist',
#       'uri': 'spotify:artist:45eNHdiiabvmbp4erw26rg'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7AzjETXRUKNRSJHMW9GIqd'},
#       'href': 'https://api.spotify.com/v1/artists/7AzjETXRUKNRSJHMW9GIqd',
#       'id': '7AzjETXRUKNRSJHMW9GIqd',
#       'name': 'Nina Nesbitt',
#       'type': 'artist',
#       'uri': 'spotify:artist:7AzjETXRUKNRSJHMW9GIqd'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 224615,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB12207330'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1jukXn6UshHV38TGiTHsvm'},
#     'href': 'https://api.spotify.com/v1/tracks/1jukXn6UshHV38TGiTHsvm',
#     'id': '1jukXn6UshHV38TGiTHsvm',
#     'is_local': False,
#     'name': 'Luv Me A Little',
#     'popularity': 36,
#     'preview_url': 'https://p.scdn.co/mp3-preview/069369eaa1075368692d474436f6a3b84988912d?cid=11ff7112cf044de8bb8626fb93505bbc',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1jukXn6UshHV38TGiTHsvm'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5xKVALj2MSqOHmQhburCM8'},
#        'href': 'https://api.spotify.com/v1/artists/5xKVALj2MSqOHmQhburCM8',
#        'id': '5xKVALj2MSqOHmQhburCM8',
#        'name': 'Tanner Adell',
#        'type': 'artist',
#        'uri': 'spotify:artist:5xKVALj2MSqOHmQhburCM8'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5bWiVnH44bQQ4zeN0ozz5W'},
#      'href': 'https://api.spotify.com/v1/albums/5bWiVnH44bQQ4zeN0ozz5W',
#      'id': '5bWiVnH44bQQ4zeN0ozz5W',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273580d22fbf94bf86303c26d43',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02580d22fbf94bf86303c26d43',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851580d22fbf94bf86303c26d43',
#        'width': 64}],
#      'name': 'Love You a Little Bit',
#      'release_date': '2022-06-27',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5bWiVnH44bQQ4zeN0ozz5W'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5xKVALj2MSqOHmQhburCM8'},
#       'href': 'https://api.spotify.com/v1/artists/5xKVALj2MSqOHmQhburCM8',
#       'id': '5xKVALj2MSqOHmQhburCM8',
#       'name': 'Tanner Adell',
#       'type': 'artist',
#       'uri': 'spotify:artist:5xKVALj2MSqOHmQhburCM8'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 210813,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM12300169'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0isqpzdmr2hsKb50uBSCdo'},
#     'href': 'https://api.spotify.com/v1/tracks/0isqpzdmr2hsKb50uBSCdo',
#     'id': '0isqpzdmr2hsKb50uBSCdo',
#     'is_local': False,
#     'name': 'Love You a Little Bit',
#     'popularity': 57,
#     'preview_url': 'https://p.scdn.co/mp3-preview/57c06f9772808273f0bbbae4768d8f0272ea6beb?cid=11ff7112cf044de8bb8626fb93505bbc',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0isqpzdmr2hsKb50uBSCdo'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/45eNHdiiabvmbp4erw26rg'},
#        'href': 'https://api.spotify.com/v1/artists/45eNHdiiabvmbp4erw26rg',
#        'id': '45eNHdiiabvmbp4erw26rg',
#        'name': 'ILLENIUM',
#        'type': 'artist',
#        'uri': 'spotify:artist:45eNHdiiabvmbp4erw26rg'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/7AzjETXRUKNRSJHMW9GIqd'},
#        'href': 'https://api.spotify.com/v1/artists/7AzjETXRUKNRSJHMW9GIqd',
#        'id': '7AzjETXRUKNRSJHMW9GIqd',
#        'name': 'Nina Nesbitt',
#        'type': 'artist',
#        'uri': 'spotify:artist:7AzjETXRUKNRSJHMW9GIqd'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Wg2b4Mp42gicxEeDNawf7'},
#        'href': 'https://api.spotify.com/v1/artists/5Wg2b4Mp42gicxEeDNawf7',
#        'id': '5Wg2b4Mp42gicxEeDNawf7',
#        'name': 'A7S',
#        'type': 'artist',
#        'uri': 'spotify:artist:5Wg2b4Mp42gicxEeDNawf7'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4wLCDwwF2uaKj1susQ0yHt'},
#      'href': 'https://api.spotify.com/v1/albums/4wLCDwwF2uaKj1susQ0yHt',
#      'id': '4wLCDwwF2uaKj1susQ0yHt',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739d7d8a040b9818d79b3c4454',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029d7d8a040b9818d79b3c4454',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519d7d8a040b9818d79b3c4454',
#        'width': 64}],
#      'name': 'Luv Me A Little (A7S DnB Remix)',
#      'release_date': '2023-02-17',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:4wLCDwwF2uaKj1susQ0yHt'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/45eNHdiiabvmbp4erw26rg'},
#       'href': 'https://api.spotify.com/v1/artists/45eNHdiiabvmbp4erw26rg',
#       'id': '45eNHdiiabvmbp4erw26rg',
#       'name': 'ILLENIUM',
#       'type': 'artist',
#       'uri': 'spotify:artist:45eNHdiiabvmbp4erw26rg'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7AzjETXRUKNRSJHMW9GIqd'},
#       'href': 'https://api.spotify.com/v1/artists/7AzjETXRUKNRSJHMW9GIqd',
#       'id': '7AzjETXRUKNRSJHMW9GIqd',
#       'name': 'Nina Nesbitt',
#       'type': 'artist',
#       'uri': 'spotify:artist:7AzjETXRUKNRSJHMW9GIqd'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Wg2b4Mp42gicxEeDNawf7'},
#       'href': 'https://api.spotify.com/v1/artists/5Wg2b4Mp42gicxEeDNawf7',
#       'id': '5Wg2b4Mp42gicxEeDNawf7',
#       'name': 'A7S',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Wg2b4Mp42gicxEeDNawf7'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 189176,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB12300247'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5R6yUk1lZDXesDRH0rCbwj'},
#     'href': 'https://api.spotify.com/v1/tracks/5R6yUk1lZDXesDRH0rCbwj',
#     'id': '5R6yUk1lZDXesDRH0rCbwj',
#     'is_local': False,
#     'name': 'Luv Me A Little - A7S DnB Remix',
#     'popularity': 38,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ab84059bdf45a11b80b280295111daba81401750?cid=11ff7112cf044de8bb8626fb93505bbc',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5R6yUk1lZDXesDRH0rCbwj'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/21WS9wngs9AqFckK7yYJPM'},
#        'href': 'https://api.spotify.com/v1/artists/21WS9wngs9AqFckK7yYJPM',
#        'id': '21WS9wngs9AqFckK7yYJPM',
#        'name': 'PnB Rock',
#        'type': 'artist',
#        'uri': 'spotify:artist:21WS9wngs9AqFckK7yYJPM'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5eJKFgn1w9nPytqjnt1x0s'},
#      'href': 'https://api.spotify.com/v1/albums/5eJKFgn1w9nPytqjnt1x0s',
#      'id': '5eJKFgn1w9nPytqjnt1x0s',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739e5498f2987ffb14d466138a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029e5498f2987ffb14d466138a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519e5498f2987ffb14d466138a',
#        'width': 64}],
#      'name': 'Luv Me Again',
#      'release_date': '2022-09-02',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5eJKFgn1w9nPytqjnt1x0s'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/21WS9wngs9AqFckK7yYJPM'},
#       'href': 'https://api.spotify.com/v1/artists/21WS9wngs9AqFckK7yYJPM',
#       'id': '21WS9wngs9AqFckK7yYJPM',
#       'name': 'PnB Rock',
#       'type': 'artist',
#       'uri': 'spotify:artist:21WS9wngs9AqFckK7yYJPM'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XC',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 127929,
#     'explicit': False,
#     'external_ids': {'isrc': 'CH7811106690'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6jXaJ37W4yKIBOEMpjGlli'},
#     'href': 'https://api.spotify.com/v1/tracks/6jXaJ37W4yKIBOEMpjGlli',
#     'id': '6jXaJ37W4yKIBOEMpjGlli',
#     'is_local': False,
#     'name': 'Luv Me Again',
#     'popularity': 56,
#     'preview_url': 'https://p.scdn.co/mp3-preview/33f41c89780e9ab44982c5c927d63ac33f430a25?cid=11ff7112cf044de8bb8626fb93505bbc',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6jXaJ37W4yKIBOEMpjGlli'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/21VBNkZvKxrI9zmfFRxXvn'},
#        'href': 'https://api.spotify.com/v1/artists/21VBNkZvKxrI9zmfFRxXvn',
#        'id': '21VBNkZvKxrI9zmfFRxXvn',
#        'name': '8-Bit Arcade',
#        'type': 'artist',
#        'uri': 'spotify:artist:21VBNkZvKxrI9zmfFRxXvn'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6Q6962vhOTel7e6jpQpCx5'},
#      'href': 'https://api.spotify.com/v1/albums/6Q6962vhOTel7e6jpQpCx5',
#      'id': '6Q6962vhOTel7e6jpQpCx5',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273683e6fec19896662636e0e9c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02683e6fec19896662636e0e9c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851683e6fec19896662636e0e9c',
#        'width': 64}],
#      'name': 'By Request, Vol. 199',
#      'release_date': '2023-02-15',
#      'release_date_precision': 'day',
#      'total_tracks': 87,
#      'type': 'album',
#      'uri': 'spotify:album:6Q6962vhOTel7e6jpQpCx5'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/21VBNkZvKxrI9zmfFRxXvn'},
#       'href': 'https://api.spotify.com/v1/artists/21VBNkZvKxrI9zmfFRxXvn',
#       'id': '21VBNkZvKxrI9zmfFRxXvn',
#       'name': '8-Bit Arcade',
#       'type': 'artist',
#       'uri': 'spotify:artist:21VBNkZvKxrI9zmfFRxXvn'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XC',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 220461,
#     'explicit': False,
#     'external_ids': {'isrc': 'AUXN22291306'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0Xexp0LEtN6TDmQMb03X4i'},
#     'href': 'https://api.spotify.com/v1/tracks/0Xexp0LEtN6TDmQMb03X4i',
#     'id': '0Xexp0LEtN6TDmQMb03X4i',
#     'is_local': False,
#     'name': 'Luv Me a Little (8-Bit Computer Game Version)',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b780937502367cbb31b5a236d16fc9cbe08f3588?cid=11ff7112cf044de8bb8626fb93505bbc',
#     'track_number': 44,
#     'type': 'track',
#     'uri': 'spotify:track:0Xexp0LEtN6TDmQMb03X4i'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/44pP5tBedbl0kJ5OWNBZK4'},
#        'href': 'https://api.spotify.com/v1/artists/44pP5tBedbl0kJ5OWNBZK4',
#        'id': '44pP5tBedbl0kJ5OWNBZK4',
#        'name': 'Simone Del Freo',
#        'type': 'artist',
#        'uri': 'spotify:artist:44pP5tBedbl0kJ5OWNBZK4'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
# ...
#       'name': 'Lil Wayne',
#       'type': 'artist',
#       'uri': 'spotify:artist:55Aa2cqylxrFIXC767Z865'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/45a6gCQWq61lIUDmr1tKuO'},
#       'href': 'https://api.spotify.com/v1/artists/45a6gCQWq61lIUDmr1tKuO',
#       'id': '45a6gCQWq61lIUDmr1tKuO',
#       'name': 'Bun B',
#       'type': 'artist',
#       'uri': 'spotify:artist:45a6gCQWq61lIUDmr1tKuO'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'RW',
#      'TG',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 278333,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUR19801116'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1WbGNQ1ydU1JGz4HTmlYmD'},
#     'href': 'https://api.spotify.com/v1/tracks/1WbGNQ1ydU1JGz4HTmlYmD',
#     'id': '1WbGNQ1ydU1JGz4HTmlYmD',
#     'is_local': False,
#     'name': "Playboy (Don't Hate Me)",
#     'popularity': 9,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d1f00c1d42edc8c1e1b4ddb8ca651245cdcf6644?cid=11ff7112cf044de8bb8626fb93505bbc',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1WbGNQ1ydU1JGz4HTmlYmD'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3OsCuQNpBRiaOAtpUW8s2S'},
#        'href': 'https://api.spotify.com/v1/artists/3OsCuQNpBRiaOAtpUW8s2S',
#        'id': '3OsCuQNpBRiaOAtpUW8s2S',
#        'name': 'zinoblade',
#        'type': 'artist',
#        'uri': 'spotify:artist:3OsCuQNpBRiaOAtpUW8s2S'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7Eclta8ggLTl4mCWN4LNbt'},
#      'href': 'https://api.spotify.com/v1/albums/7Eclta8ggLTl4mCWN4LNbt',
#      'id': '7Eclta8ggLTl4mCWN4LNbt',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735d450a0cc9323dc7087a7b4b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025d450a0cc9323dc7087a7b4b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515d450a0cc9323dc7087a7b4b',
#        'width': 64}],
#      'name': 'luv me 2',
#      'release_date': '2021-05-10',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:7Eclta8ggLTl4mCWN4LNbt'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3OsCuQNpBRiaOAtpUW8s2S'},
#       'href': 'https://api.spotify.com/v1/artists/3OsCuQNpBRiaOAtpUW8s2S',
#       'id': '3OsCuQNpBRiaOAtpUW8s2S',
#       'name': 'zinoblade',
#       'type': 'artist',
#       'uri': 'spotify:artist:3OsCuQNpBRiaOAtpUW8s2S'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XC',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 145763,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZDA52212468'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7A166ydWbnZxh1z9yzGso2'},
#     'href': 'https://api.spotify.com/v1/tracks/7A166ydWbnZxh1z9yzGso2',
#     'id': '7A166ydWbnZxh1z9yzGso2',
#     'is_local': False,
#     'name': 'luv me 2',
#     'popularity': 27,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a06c6680fdf48267bb427554676c7c9972b40278?cid=11ff7112cf044de8bb8626fb93505bbc',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7A166ydWbnZxh1z9yzGso2'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1ldk9xiTCXR0rVCugBTBgC'},
#        'href': 'https://api.spotify.com/v1/artists/1ldk9xiTCXR0rVCugBTBgC',
#        'id': '1ldk9xiTCXR0rVCugBTBgC',
#        'name': 'Soar Thumb',
#        'type': 'artist',
#        'uri': 'spotify:artist:1ldk9xiTCXR0rVCugBTBgC'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/14NumzSRp5MFaHowHdTIeM'},
#      'href': 'https://api.spotify.com/v1/albums/14NumzSRp5MFaHowHdTIeM',
#      'id': '14NumzSRp5MFaHowHdTIeM',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738e502335bd521dcc75e618e4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028e502335bd521dcc75e618e4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518e502335bd521dcc75e618e4',
#        'width': 64}],
#      'name': 'The Nexus (Instrumentals)',
#      'release_date': '2019-05-08',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:14NumzSRp5MFaHowHdTIeM'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1ldk9xiTCXR0rVCugBTBgC'},
#       'href': 'https://api.spotify.com/v1/artists/1ldk9xiTCXR0rVCugBTBgC',
#       'id': '1ldk9xiTCXR0rVCugBTBgC',
#       'name': 'Soar Thumb',
#       'type': 'artist',
#       'uri': 'spotify:artist:1ldk9xiTCXR0rVCugBTBgC'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XC',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 193462,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZFYW1958767'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7DmZVUKiOCPuYWx4l21dEt'},
#     'href': 'https://api.spotify.com/v1/tracks/7DmZVUKiOCPuYWx4l21dEt',
#     'id': '7DmZVUKiOCPuYWx4l21dEt',
#     'is_local': False,
#     'name': 'Art of Score',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1fba66eff946b6a46d8a4ae918244dfabb8e7740?cid=11ff7112cf044de8bb8626fb93505bbc',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:7DmZVUKiOCPuYWx4l21dEt'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=Luv+me+a+little&type=track&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 277}}

# %%
spotify.get_artist("45eNHdiiabvmbp4erw26rg")
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/45eNHdiiabvmbp4erw26rg'},
#  'followers': {'href': None, 'total': 1349118},
#  'genres': ['edm', 'melodic dubstep', 'pop', 'pop dance', 'tropical house'],
#  'href': 'https://api.spotify.com/v1/artists/45eNHdiiabvmbp4erw26rg',
#  'id': '45eNHdiiabvmbp4erw26rg',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab6761610000e5eb81a0ab3a9a4326929a01b0f1',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/ab6761610000517481a0ab3a9a4326929a01b0f1',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ab6761610000f17881a0ab3a9a4326929a01b0f1',
#    'width': 160}],
#  'name': 'ILLENIUM',
#  'popularity': 75,
#  'type': 'artist',
#  'uri': 'spotify:artist:45eNHdiiabvmbp4erw26rg'}
