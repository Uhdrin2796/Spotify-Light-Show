# %%
import requests
import datetime
import base64
from urllib.parse import urlencode

# %%
client_id = "11ff7112cf044de8bb8626fb93505bbc"
client_secret = "551ab8978f3d4ea5a1c57ce762373ae7"

# %%
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url = "https://accounts.spotify.com/api/token"
    base_url = "https://api.spotify.com/v1"
    method = "POST"
    
    
    def __init__(self,client_id,client_secret,*args, **kwargs):
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret =client_secret
        
    def get_client_credentials(self):
        """"""
        "Returns a base64 encoded string"
        """"""
        client_id = self.client_id
        client_secret = self.client_secret
        if client_secret == None or client_id == None:
            raise Exemption("You must set client_id and client_secret")
        client_creds = f"{client_id}:{client_secret}" #Client details as string
        client_creds_b64 =base64.b64encode(client_creds.encode()) #Turn string into base64 type
        return client_creds_b64.decode() #Return as decoded base64 string
        
    def get_token_headers(self):
        
        client_creds_b64 = self.get_client_credentials() #get decoded client credentials.
        return {
            "Authorization" : f"Basic {client_creds_b64}" 
        }
    def get_token_data(self):
        return {
            "grant_type":"client_credentials"
        }
    
    def perform_auth(self):
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_headers()
        r = requests.post(token_url, data=token_data, headers=token_headers)
        if r.status_code not in range(200,299):
            raise Exception("Could not authenticate client")
            #return False
        data = r.json()
        now = datetime.datetime.now()
        access_token = data['access_token']
        self.access_token = access_token
        expires_in = data['expires_in'] #in seconds
        token_type = data['token_type'] 
        expires = now + datetime.timedelta(seconds=expires_in)
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        return True
        
    def get_access_token(self):
        token = self.access_token
        expires = self.access_token_expires
        now = datetime.datetime.now()
        if expires < now:
            self.perform_auth()
            return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token()
        return token
    
    def get_resource_headers(self):
        access_token = self.get_access_token()
        headers = {
            "Authorization" : f"Bearer {access_token}"
        }
        return headers
    
    def get_id(self,):
        pass
    
    def get_resource(self, lookup_id, resource_type='albums',version='v1'):
        endpoint = f"https://api.spotify.com/{version}/{resource_type}/{lookup_id}"
        headers = self.get_resource_headers()
        r = requests.get(endpoint, headers = headers)
        if r.status_code not in range(200,299):
            return {}
        return r.json()
        
    def get_album(self, _id):
        return self.get_resource(_id, resource_type='albums')
    
    def get_artist(self, _id):
        return self.get_resource(_id, resource_type='artists')
    
    def get_track(self,):
        pass
    def get_track_features(self,):
        pass
    def get_audio_analysis(self,):
        pass
        
    def base_search(self, query_params): #type is a built-in python operator
        headers = self.get_resource_headers()
        endpoint = "https://api.spotify.com/v1/search"
        lookup_url = f"{endpoint}?{query_params}"
        print(lookup_url)
        r = requests.get(lookup_url, headers=headers)
        print(r.status_code)
        if r.status_code not in range(200,299):
            return {}
        return r.json()
    
    def search(self, query=None, operator=None, operator_query=None,search_type='artist'):
        if query == None:
            raise Exception("A query is required")
        if isinstance(query,dict):
            query = " ".join([f"{k}:{v}" for k,v in query.items()])
        if operator != None and operator_query != None:
            if operator == "or" or operator.lower() == "not":
                operator = operator.upper()
                if isinstance(operator_query, str):
                    query = f"{query} {operator} {operator_query}"
            operator = operator.upper()
        query_params = urlencode({"q": query, "type": search_type.lower()})
        print(query_params)
        return self.base_search(query_params)

# %%
spotify = SpotifyAPI(client_id,client_secret)

# %%
spotify.search({"track":"Luv me a little","artist":"Illenium"}, search_type="track")
# Out:
# q=track%3ALuv+me+a+little+artist%3AIllenium&type=track
# https://api.spotify.com/v1/search?q=track%3ALuv+me+a+little+artist%3AIllenium&type=track
# 200
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=track%3ALuv+me+a+little+artist%3AIllenium&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/45eNHdiiabvmbp4erw26rg'},
#        'href': 'https://api.spotify.com/v1/artists/45eNHdiiabvmbp4erw26rg',
#        'id': '45eNHdiiabvmbp4erw26rg',
#        'name': 'ILLENIUM',
#        'type': 'artist',
#        'uri': 'spotify:artist:45eNHdiiabvmbp4erw26rg'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/7AzjETXRUKNRSJHMW9GIqd'},
#        'href': 'https://api.spotify.com/v1/artists/7AzjETXRUKNRSJHMW9GIqd',
#        'id': '7AzjETXRUKNRSJHMW9GIqd',
#        'name': 'Nina Nesbitt',
#        'type': 'artist',
#        'uri': 'spotify:artist:7AzjETXRUKNRSJHMW9GIqd'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7rZOkDS1qDISQN3kValLId'},
#      'href': 'https://api.spotify.com/v1/albums/7rZOkDS1qDISQN3kValLId',
#      'id': '7rZOkDS1qDISQN3kValLId',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732c63e6bc06a8b23366662cd5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022c63e6bc06a8b23366662cd5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512c63e6bc06a8b23366662cd5',
#        'width': 64}],
#      'name': 'Luv Me A Little',
#      'release_date': '2023-01-20',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:7rZOkDS1qDISQN3kValLId'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/45eNHdiiabvmbp4erw26rg'},
#       'href': 'https://api.spotify.com/v1/artists/45eNHdiiabvmbp4erw26rg',
#       'id': '45eNHdiiabvmbp4erw26rg',
#       'name': 'ILLENIUM',
#       'type': 'artist',
#       'uri': 'spotify:artist:45eNHdiiabvmbp4erw26rg'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7AzjETXRUKNRSJHMW9GIqd'},
#       'href': 'https://api.spotify.com/v1/artists/7AzjETXRUKNRSJHMW9GIqd',
#       'id': '7AzjETXRUKNRSJHMW9GIqd',
#       'name': 'Nina Nesbitt',
#       'type': 'artist',
#       'uri': 'spotify:artist:7AzjETXRUKNRSJHMW9GIqd'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 224615,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB12207330'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1SFA5zEVOsLhEg7ynbvQFT'},
#     'href': 'https://api.spotify.com/v1/tracks/1SFA5zEVOsLhEg7ynbvQFT',
#     'id': '1SFA5zEVOsLhEg7ynbvQFT',
#     'is_local': False,
#     'name': 'Luv Me A Little',
#     'popularity': 69,
#     'preview_url': 'https://p.scdn.co/mp3-preview/069369eaa1075368692d474436f6a3b84988912d?cid=11ff7112cf044de8bb8626fb93505bbc',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1SFA5zEVOsLhEg7ynbvQFT'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/45eNHdiiabvmbp4erw26rg'},
#        'href': 'https://api.spotify.com/v1/artists/45eNHdiiabvmbp4erw26rg',
#        'id': '45eNHdiiabvmbp4erw26rg',
#        'name': 'ILLENIUM',
#        'type': 'artist',
#        'uri': 'spotify:artist:45eNHdiiabvmbp4erw26rg'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/7AzjETXRUKNRSJHMW9GIqd'},
#        'href': 'https://api.spotify.com/v1/artists/7AzjETXRUKNRSJHMW9GIqd',
#        'id': '7AzjETXRUKNRSJHMW9GIqd',
#        'name': 'Nina Nesbitt',
#        'type': 'artist',
#        'uri': 'spotify:artist:7AzjETXRUKNRSJHMW9GIqd'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Wg2b4Mp42gicxEeDNawf7'},
#        'href': 'https://api.spotify.com/v1/artists/5Wg2b4Mp42gicxEeDNawf7',
#        'id': '5Wg2b4Mp42gicxEeDNawf7',
#        'name': 'A7S',
#        'type': 'artist',
#        'uri': 'spotify:artist:5Wg2b4Mp42gicxEeDNawf7'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4wLCDwwF2uaKj1susQ0yHt'},
#      'href': 'https://api.spotify.com/v1/albums/4wLCDwwF2uaKj1susQ0yHt',
#      'id': '4wLCDwwF2uaKj1susQ0yHt',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739d7d8a040b9818d79b3c4454',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029d7d8a040b9818d79b3c4454',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519d7d8a040b9818d79b3c4454',
#        'width': 64}],
#      'name': 'Luv Me A Little (A7S DnB Remix)',
#      'release_date': '2023-02-17',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:4wLCDwwF2uaKj1susQ0yHt'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/45eNHdiiabvmbp4erw26rg'},
#       'href': 'https://api.spotify.com/v1/artists/45eNHdiiabvmbp4erw26rg',
#       'id': '45eNHdiiabvmbp4erw26rg',
#       'name': 'ILLENIUM',
#       'type': 'artist',
#       'uri': 'spotify:artist:45eNHdiiabvmbp4erw26rg'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7AzjETXRUKNRSJHMW9GIqd'},
#       'href': 'https://api.spotify.com/v1/artists/7AzjETXRUKNRSJHMW9GIqd',
#       'id': '7AzjETXRUKNRSJHMW9GIqd',
#       'name': 'Nina Nesbitt',
#       'type': 'artist',
#       'uri': 'spotify:artist:7AzjETXRUKNRSJHMW9GIqd'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 224615,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB12207330'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1jukXn6UshHV38TGiTHsvm'},
#     'href': 'https://api.spotify.com/v1/tracks/1jukXn6UshHV38TGiTHsvm',
#     'id': '1jukXn6UshHV38TGiTHsvm',
#     'is_local': False,
#     'name': 'Luv Me A Little',
#     'popularity': 36,
#     'preview_url': 'https://p.scdn.co/mp3-preview/069369eaa1075368692d474436f6a3b84988912d?cid=11ff7112cf044de8bb8626fb93505bbc',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1jukXn6UshHV38TGiTHsvm'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/45eNHdiiabvmbp4erw26rg'},
#        'href': 'https://api.spotify.com/v1/artists/45eNHdiiabvmbp4erw26rg',
#        'id': '45eNHdiiabvmbp4erw26rg',
#        'name': 'ILLENIUM',
#        'type': 'artist',
#        'uri': 'spotify:artist:45eNHdiiabvmbp4erw26rg'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/7AzjETXRUKNRSJHMW9GIqd'},
#        'href': 'https://api.spotify.com/v1/artists/7AzjETXRUKNRSJHMW9GIqd',
#        'id': '7AzjETXRUKNRSJHMW9GIqd',
#        'name': 'Nina Nesbitt',
#        'type': 'artist',
#        'uri': 'spotify:artist:7AzjETXRUKNRSJHMW9GIqd'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Wg2b4Mp42gicxEeDNawf7'},
#        'href': 'https://api.spotify.com/v1/artists/5Wg2b4Mp42gicxEeDNawf7',
#        'id': '5Wg2b4Mp42gicxEeDNawf7',
#        'name': 'A7S',
#        'type': 'artist',
#        'uri': 'spotify:artist:5Wg2b4Mp42gicxEeDNawf7'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4wLCDwwF2uaKj1susQ0yHt'},
#      'href': 'https://api.spotify.com/v1/albums/4wLCDwwF2uaKj1susQ0yHt',
#      'id': '4wLCDwwF2uaKj1susQ0yHt',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739d7d8a040b9818d79b3c4454',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029d7d8a040b9818d79b3c4454',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519d7d8a040b9818d79b3c4454',
#        'width': 64}],
#      'name': 'Luv Me A Little (A7S DnB Remix)',
#      'release_date': '2023-02-17',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:4wLCDwwF2uaKj1susQ0yHt'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/45eNHdiiabvmbp4erw26rg'},
#       'href': 'https://api.spotify.com/v1/artists/45eNHdiiabvmbp4erw26rg',
#       'id': '45eNHdiiabvmbp4erw26rg',
#       'name': 'ILLENIUM',
#       'type': 'artist',
#       'uri': 'spotify:artist:45eNHdiiabvmbp4erw26rg'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7AzjETXRUKNRSJHMW9GIqd'},
#       'href': 'https://api.spotify.com/v1/artists/7AzjETXRUKNRSJHMW9GIqd',
#       'id': '7AzjETXRUKNRSJHMW9GIqd',
#       'name': 'Nina Nesbitt',
#       'type': 'artist',
#       'uri': 'spotify:artist:7AzjETXRUKNRSJHMW9GIqd'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Wg2b4Mp42gicxEeDNawf7'},
#       'href': 'https://api.spotify.com/v1/artists/5Wg2b4Mp42gicxEeDNawf7',
#       'id': '5Wg2b4Mp42gicxEeDNawf7',
#       'name': 'A7S',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Wg2b4Mp42gicxEeDNawf7'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 189176,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB12300247'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5R6yUk1lZDXesDRH0rCbwj'},
#     'href': 'https://api.spotify.com/v1/tracks/5R6yUk1lZDXesDRH0rCbwj',
#     'id': '5R6yUk1lZDXesDRH0rCbwj',
#     'is_local': False,
#     'name': 'Luv Me A Little - A7S DnB Remix',
#     'popularity': 38,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ab84059bdf45a11b80b280295111daba81401750?cid=11ff7112cf044de8bb8626fb93505bbc',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5R6yUk1lZDXesDRH0rCbwj'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BG',
#       'BH',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BZ',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DM',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GB',
#       'GD',
#       'GE',
#       'GR',
#       'GT',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KG',
#       'KH',
#       'KI',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MD',
#       'ME',
#       'MH',
#       'MK',
#       'MN',
#       'MO',
#       'MT',
#       'MV',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'SA',
#       'SB',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SM',
#       'SR',
#       'SV',
#       'TH',
#       'TJ',
#       'TL',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/75e6Bqjk892UUJdyyY03Fo'},
#      'href': 'https://api.spotify.com/v1/albums/75e6Bqjk892UUJdyyY03Fo',
#      'id': '75e6Bqjk892UUJdyyY03Fo',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27313175c8c8110c2d084411562',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0213175c8c8110c2d084411562',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485113175c8c8110c2d084411562',
#        'width': 64}],
#      'name': "20's Love Songs",
#      'release_date': '2023-02-20',
#      'release_date_precision': 'day',
#      'total_tracks': 35,
#      'type': 'album',
#      'uri': 'spotify:album:75e6Bqjk892UUJdyyY03Fo'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/45eNHdiiabvmbp4erw26rg'},
#       'href': 'https://api.spotify.com/v1/artists/45eNHdiiabvmbp4erw26rg',
#       'id': '45eNHdiiabvmbp4erw26rg',
#       'name': 'ILLENIUM',
#       'type': 'artist',
#       'uri': 'spotify:artist:45eNHdiiabvmbp4erw26rg'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7AzjETXRUKNRSJHMW9GIqd'},
#       'href': 'https://api.spotify.com/v1/artists/7AzjETXRUKNRSJHMW9GIqd',
#       'id': '7AzjETXRUKNRSJHMW9GIqd',
#       'name': 'Nina Nesbitt',
#       'type': 'artist',
#       'uri': 'spotify:artist:7AzjETXRUKNRSJHMW9GIqd'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'CW',
#      'DM',
#      'FJ',
#      'GE',
#      'GD',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'MV',
#      'MH',
#      'FM',
#      'NR',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'KH',
#      'KG',
#      'LA',
#      'MO',
#      'MN',
#      'NP',
#      'UZ',
#      'IQ',
#      'TJ',
#      'VE',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 224615,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB12207330'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0GJAlocJ1B4N3uFAXXuByl'},
#     'href': 'https://api.spotify.com/v1/tracks/0GJAlocJ1B4N3uFAXXuByl',
#     'id': '0GJAlocJ1B4N3uFAXXuByl',
#     'is_local': False,
#     'name': 'Luv Me a Little',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/069369eaa1075368692d474436f6a3b84988912d?cid=11ff7112cf044de8bb8626fb93505bbc',
#     'track_number': 20,
#     'type': 'track',
#     'uri': 'spotify:track:0GJAlocJ1B4N3uFAXXuByl'}],
#   'limit': 20,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 4}}

# %%
spotify.search(query = "Luv me a little", operator ="NOT", operator_query="8-Bit", search_type="track")
# Out:
# q=Luv+me+a+little+NOT+8-Bit&type=track
# https://api.spotify.com/v1/search?q=Luv+me+a+little+NOT+8-Bit&type=track
# 200
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Luv+me+a+little+NOT+8-Bit&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/45eNHdiiabvmbp4erw26rg'},
#        'href': 'https://api.spotify.com/v1/artists/45eNHdiiabvmbp4erw26rg',
#        'id': '45eNHdiiabvmbp4erw26rg',
#        'name': 'ILLENIUM',
#        'type': 'artist',
#        'uri': 'spotify:artist:45eNHdiiabvmbp4erw26rg'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/7AzjETXRUKNRSJHMW9GIqd'},
#        'href': 'https://api.spotify.com/v1/artists/7AzjETXRUKNRSJHMW9GIqd',
#        'id': '7AzjETXRUKNRSJHMW9GIqd',
#        'name': 'Nina Nesbitt',
#        'type': 'artist',
#        'uri': 'spotify:artist:7AzjETXRUKNRSJHMW9GIqd'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7rZOkDS1qDISQN3kValLId'},
#      'href': 'https://api.spotify.com/v1/albums/7rZOkDS1qDISQN3kValLId',
#      'id': '7rZOkDS1qDISQN3kValLId',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732c63e6bc06a8b23366662cd5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022c63e6bc06a8b23366662cd5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512c63e6bc06a8b23366662cd5',
#        'width': 64}],
#      'name': 'Luv Me A Little',
#      'release_date': '2023-01-20',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:7rZOkDS1qDISQN3kValLId'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/45eNHdiiabvmbp4erw26rg'},
#       'href': 'https://api.spotify.com/v1/artists/45eNHdiiabvmbp4erw26rg',
#       'id': '45eNHdiiabvmbp4erw26rg',
#       'name': 'ILLENIUM',
#       'type': 'artist',
#       'uri': 'spotify:artist:45eNHdiiabvmbp4erw26rg'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7AzjETXRUKNRSJHMW9GIqd'},
#       'href': 'https://api.spotify.com/v1/artists/7AzjETXRUKNRSJHMW9GIqd',
#       'id': '7AzjETXRUKNRSJHMW9GIqd',
#       'name': 'Nina Nesbitt',
#       'type': 'artist',
#       'uri': 'spotify:artist:7AzjETXRUKNRSJHMW9GIqd'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 224615,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB12207330'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1SFA5zEVOsLhEg7ynbvQFT'},
#     'href': 'https://api.spotify.com/v1/tracks/1SFA5zEVOsLhEg7ynbvQFT',
#     'id': '1SFA5zEVOsLhEg7ynbvQFT',
#     'is_local': False,
#     'name': 'Luv Me A Little',
#     'popularity': 69,
#     'preview_url': 'https://p.scdn.co/mp3-preview/069369eaa1075368692d474436f6a3b84988912d?cid=11ff7112cf044de8bb8626fb93505bbc',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1SFA5zEVOsLhEg7ynbvQFT'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4J6UXkUpIArZbKXhh0cOC2'},
#        'href': 'https://api.spotify.com/v1/artists/4J6UXkUpIArZbKXhh0cOC2',
#        'id': '4J6UXkUpIArZbKXhh0cOC2',
#        'name': 'Your Favorite Martian',
#        'type': 'artist',
#        'uri': 'spotify:artist:4J6UXkUpIArZbKXhh0cOC2'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0ETs55D6Nj5h5SitfpeJDk'},
#      'href': 'https://api.spotify.com/v1/albums/0ETs55D6Nj5h5SitfpeJDk',
#      'id': '0ETs55D6Nj5h5SitfpeJDk',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273cb02c6c665a02ce31c72ad6e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02cb02c6c665a02ce31c72ad6e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851cb02c6c665a02ce31c72ad6e',
#        'width': 64}],
#      'name': '8-Bit World',
#      'release_date': '2011-09-16',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0ETs55D6Nj5h5SitfpeJDk'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4J6UXkUpIArZbKXhh0cOC2'},
#       'href': 'https://api.spotify.com/v1/artists/4J6UXkUpIArZbKXhh0cOC2',
#       'id': '4J6UXkUpIArZbKXhh0cOC2',
#       'name': 'Your Favorite Martian',
#       'type': 'artist',
#       'uri': 'spotify:artist:4J6UXkUpIArZbKXhh0cOC2'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/382aq8Pij5V2nE2JMHMoxl'},
#       'href': 'https://api.spotify.com/v1/artists/382aq8Pij5V2nE2JMHMoxl',
#       'id': '382aq8Pij5V2nE2JMHMoxl',
#       'name': 'Hoodie Allen',
#       'type': 'artist',
#       'uri': 'spotify:artist:382aq8Pij5V2nE2JMHMoxl'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 195692,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCAAZ1184396'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7IpGcByrh5dhyOwwaoiypG'},
#     'href': 'https://api.spotify.com/v1/tracks/7IpGcByrh5dhyOwwaoiypG',
#     'id': '7IpGcByrh5dhyOwwaoiypG',
#     'is_local': False,
#     'name': '8-Bit World',
#     'popularity': 32,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8008fc39ed6dcb6c3cb8c15364efff261469257a?cid=11ff7112cf044de8bb8626fb93505bbc',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7IpGcByrh5dhyOwwaoiypG'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/45eNHdiiabvmbp4erw26rg'},
#        'href': 'https://api.spotify.com/v1/artists/45eNHdiiabvmbp4erw26rg',
#        'id': '45eNHdiiabvmbp4erw26rg',
#        'name': 'ILLENIUM',
#        'type': 'artist',
#        'uri': 'spotify:artist:45eNHdiiabvmbp4erw26rg'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/7AzjETXRUKNRSJHMW9GIqd'},
#        'href': 'https://api.spotify.com/v1/artists/7AzjETXRUKNRSJHMW9GIqd',
#        'id': '7AzjETXRUKNRSJHMW9GIqd',
#        'name': 'Nina Nesbitt',
#        'type': 'artist',
#        'uri': 'spotify:artist:7AzjETXRUKNRSJHMW9GIqd'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Wg2b4Mp42gicxEeDNawf7'},
#        'href': 'https://api.spotify.com/v1/artists/5Wg2b4Mp42gicxEeDNawf7',
#        'id': '5Wg2b4Mp42gicxEeDNawf7',
#        'name': 'A7S',
#        'type': 'artist',
#        'uri': 'spotify:artist:5Wg2b4Mp42gicxEeDNawf7'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4wLCDwwF2uaKj1susQ0yHt'},
#      'href': 'https://api.spotify.com/v1/albums/4wLCDwwF2uaKj1susQ0yHt',
#      'id': '4wLCDwwF2uaKj1susQ0yHt',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739d7d8a040b9818d79b3c4454',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029d7d8a040b9818d79b3c4454',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519d7d8a040b9818d79b3c4454',
#        'width': 64}],
#      'name': 'Luv Me A Little (A7S DnB Remix)',
#      'release_date': '2023-02-17',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:4wLCDwwF2uaKj1susQ0yHt'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/45eNHdiiabvmbp4erw26rg'},
#       'href': 'https://api.spotify.com/v1/artists/45eNHdiiabvmbp4erw26rg',
#       'id': '45eNHdiiabvmbp4erw26rg',
#       'name': 'ILLENIUM',
#       'type': 'artist',
#       'uri': 'spotify:artist:45eNHdiiabvmbp4erw26rg'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7AzjETXRUKNRSJHMW9GIqd'},
#       'href': 'https://api.spotify.com/v1/artists/7AzjETXRUKNRSJHMW9GIqd',
#       'id': '7AzjETXRUKNRSJHMW9GIqd',
#       'name': 'Nina Nesbitt',
#       'type': 'artist',
#       'uri': 'spotify:artist:7AzjETXRUKNRSJHMW9GIqd'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 224615,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB12207330'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1jukXn6UshHV38TGiTHsvm'},
#     'href': 'https://api.spotify.com/v1/tracks/1jukXn6UshHV38TGiTHsvm',
#     'id': '1jukXn6UshHV38TGiTHsvm',
#     'is_local': False,
#     'name': 'Luv Me A Little',
#     'popularity': 36,
#     'preview_url': 'https://p.scdn.co/mp3-preview/069369eaa1075368692d474436f6a3b84988912d?cid=11ff7112cf044de8bb8626fb93505bbc',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1jukXn6UshHV38TGiTHsvm'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/38dU5p05IqvPXp2pajCFSi'},
#        'href': 'https://api.spotify.com/v1/artists/38dU5p05IqvPXp2pajCFSi',
#        'id': '38dU5p05IqvPXp2pajCFSi',
#        'name': 'AdhesiveWombat',
#        'type': 'artist',
#        'uri': 'spotify:artist:38dU5p05IqvPXp2pajCFSi'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1KxVwpjncpfhJCSGoLgmzM'},
#      'href': 'https://api.spotify.com/v1/albums/1KxVwpjncpfhJCSGoLgmzM',
#      'id': '1KxVwpjncpfhJCSGoLgmzM',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f16478a9ace552998484fa17',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f16478a9ace552998484fa17',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f16478a9ace552998484fa17',
#        'width': 64}],
#      'name': 'Marsupial Madness',
#      'release_date': '2013-06-05',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:1KxVwpjncpfhJCSGoLgmzM'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/38dU5p05IqvPXp2pajCFSi'},
#       'href': 'https://api.spotify.com/v1/artists/38dU5p05IqvPXp2pajCFSi',
#       'id': '38dU5p05IqvPXp2pajCFSi',
#       'name': 'AdhesiveWombat',
#       'type': 'artist',
#       'uri': 'spotify:artist:38dU5p05IqvPXp2pajCFSi'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XC',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 271376,
#     'explicit': False,
#     'external_ids': {'isrc': 'USDHM1413057'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5Cw6SX4MtdaOvM0GbN5g7j'},
#     'href': 'https://api.spotify.com/v1/tracks/5Cw6SX4MtdaOvM0GbN5g7j',
#     'id': '5Cw6SX4MtdaOvM0GbN5g7j',
#     'is_local': False,
#     'name': '8 Bit Adventure',
#     'popularity': 35,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c4b3fc658b9a23d5c504f6f8b21b7d011218105f?cid=11ff7112cf044de8bb8626fb93505bbc',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5Cw6SX4MtdaOvM0GbN5g7j'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/45eNHdiiabvmbp4erw26rg'},
#        'href': 'https://api.spotify.com/v1/artists/45eNHdiiabvmbp4erw26rg',
#        'id': '45eNHdiiabvmbp4erw26rg',
#        'name': 'ILLENIUM',
#        'type': 'artist',
#        'uri': 'spotify:artist:45eNHdiiabvmbp4erw26rg'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/7AzjETXRUKNRSJHMW9GIqd'},
#        'href': 'https://api.spotify.com/v1/artists/7AzjETXRUKNRSJHMW9GIqd',
#        'id': '7AzjETXRUKNRSJHMW9GIqd',
#        'name': 'Nina Nesbitt',
#        'type': 'artist',
#        'uri': 'spotify:artist:7AzjETXRUKNRSJHMW9GIqd'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Wg2b4Mp42gicxEeDNawf7'},
#        'href': 'https://api.spotify.com/v1/artists/5Wg2b4Mp42gicxEeDNawf7',
#        'id': '5Wg2b4Mp42gicxEeDNawf7',
#        'name': 'A7S',
#        'type': 'artist',
#        'uri': 'spotify:artist:5Wg2b4Mp42gicxEeDNawf7'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4wLCDwwF2uaKj1susQ0yHt'},
#      'href': 'https://api.spotify.com/v1/albums/4wLCDwwF2uaKj1susQ0yHt',
#      'id': '4wLCDwwF2uaKj1susQ0yHt',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739d7d8a040b9818d79b3c4454',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029d7d8a040b9818d79b3c4454',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519d7d8a040b9818d79b3c4454',
#        'width': 64}],
#      'name': 'Luv Me A Little (A7S DnB Remix)',
#      'release_date': '2023-02-17',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:4wLCDwwF2uaKj1susQ0yHt'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/45eNHdiiabvmbp4erw26rg'},
#       'href': 'https://api.spotify.com/v1/artists/45eNHdiiabvmbp4erw26rg',
#       'id': '45eNHdiiabvmbp4erw26rg',
#       'name': 'ILLENIUM',
#       'type': 'artist',
#       'uri': 'spotify:artist:45eNHdiiabvmbp4erw26rg'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7AzjETXRUKNRSJHMW9GIqd'},
#       'href': 'https://api.spotify.com/v1/artists/7AzjETXRUKNRSJHMW9GIqd',
#       'id': '7AzjETXRUKNRSJHMW9GIqd',
#       'name': 'Nina Nesbitt',
#       'type': 'artist',
#       'uri': 'spotify:artist:7AzjETXRUKNRSJHMW9GIqd'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Wg2b4Mp42gicxEeDNawf7'},
#       'href': 'https://api.spotify.com/v1/artists/5Wg2b4Mp42gicxEeDNawf7',
#       'id': '5Wg2b4Mp42gicxEeDNawf7',
#       'name': 'A7S',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Wg2b4Mp42gicxEeDNawf7'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 189176,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB12300247'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5R6yUk1lZDXesDRH0rCbwj'},
#     'href': 'https://api.spotify.com/v1/tracks/5R6yUk1lZDXesDRH0rCbwj',
#     'id': '5R6yUk1lZDXesDRH0rCbwj',
#     'is_local': False,
#     'name': 'Luv Me A Little - A7S DnB Remix',
#     'popularity': 38,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ab84059bdf45a11b80b280295111daba81401750?cid=11ff7112cf044de8bb8626fb93505bbc',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5R6yUk1lZDXesDRH0rCbwj'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3hvgLXeDFNiqDOVXl0xTge'},
#        'href': 'https://api.spotify.com/v1/artists/3hvgLXeDFNiqDOVXl0xTge',
#        'id': '3hvgLXeDFNiqDOVXl0xTge',
#        'name': 'LukHash',
#        'type': 'artist',
#        'uri': 'spotify:artist:3hvgLXeDFNiqDOVXl0xTge'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0SzVx3UcuwbqHmrUSBrfZy'},
#      'href': 'https://api.spotify.com/v1/albums/0SzVx3UcuwbqHmrUSBrfZy',
#      'id': '0SzVx3UcuwbqHmrUSBrfZy',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273910608bbf011f03bb0c48d01',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02910608bbf011f03bb0c48d01',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851910608bbf011f03bb0c48d01',
#        'width': 64}],
#      'name': '8-Bit Warrior',
#      'release_date': '2022-11-18',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:0SzVx3UcuwbqHmrUSBrfZy'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3hvgLXeDFNiqDOVXl0xTge'},
#       'href': 'https://api.spotify.com/v1/artists/3hvgLXeDFNiqDOVXl0xTge',
#       'id': '3hvgLXeDFNiqDOVXl0xTge',
#       'name': 'LukHash',
#       'type': 'artist',
#       'uri': 'spotify:artist:3hvgLXeDFNiqDOVXl0xTge'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XC',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 152586,
#     'explicit': False,
#     'external_ids': {'isrc': 'ushm82257910'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0c0HpK3L2K6hRSkD1laUWE'},
#     'href': 'https://api.spotify.com/v1/tracks/0c0HpK3L2K6hRSkD1laUWE',
#     'id': '0c0HpK3L2K6hRSkD1laUWE',
#     'is_local': False,
#     'name': '8-Bit Warrior',
#     'popularity': 40,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d50ba1ed8937250768aa2e67a50e766867f2281c?cid=11ff7112cf044de8bb8626fb93505bbc',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0c0HpK3L2K6hRSkD1laUWE'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BG',
#       'BH',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BZ',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DM',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GB',
#       'GD',
#       'GE',
#       'GR',
#       'GT',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KG',
#       'KH',
#       'KI',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MD',
#       'ME',
#       'MH',
#       'MK',
#       'MN',
#       'MO',
#       'MT',
#       'MV',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'SA',
#       'SB',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SM',
#       'SR',
#       'SV',
#       'TH',
#       'TJ',
#       'TL',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/75e6Bqjk892UUJdyyY03Fo'},
#      'href': 'https://api.spotify.com/v1/albums/75e6Bqjk892UUJdyyY03Fo',
#      'id': '75e6Bqjk892UUJdyyY03Fo',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27313175c8c8110c2d084411562',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0213175c8c8110c2d084411562',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485113175c8c8110c2d084411562',
#        'width': 64}],
#      'name': "20's Love Songs",
#      'release_date': '2023-02-20',
#      'release_date_precision': 'day',
#      'total_tracks': 35,
#      'type': 'album',
#      'uri': 'spotify:album:75e6Bqjk892UUJdyyY03Fo'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/45eNHdiiabvmbp4erw26rg'},
#       'href': 'https://api.spotify.com/v1/artists/45eNHdiiabvmbp4erw26rg',
#       'id': '45eNHdiiabvmbp4erw26rg',
#       'name': 'ILLENIUM',
#       'type': 'artist',
#       'uri': 'spotify:artist:45eNHdiiabvmbp4erw26rg'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7AzjETXRUKNRSJHMW9GIqd'},
#       'href': 'https://api.spotify.com/v1/artists/7AzjETXRUKNRSJHMW9GIqd',
#       'id': '7AzjETXRUKNRSJHMW9GIqd',
#       'name': 'Nina Nesbitt',
#       'type': 'artist',
#       'uri': 'spotify:artist:7AzjETXRUKNRSJHMW9GIqd'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'CW',
#      'DM',
#      'FJ',
#      'GE',
#      'GD',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'MV',
#      'MH',
#      'FM',
#      'NR',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'KH',
#      'KG',
#      'LA',
#      'MO',
#      'MN',
#      'NP',
#      'UZ',
#      'IQ',
#      'TJ',
#      'VE',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 224615,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB12207330'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0GJAlocJ1B4N3uFAXXuByl'},
#     'href': 'https://api.spotify.com/v1/tracks/0GJAlocJ1B4N3uFAXXuByl',
#     'id': '0GJAlocJ1B4N3uFAXXuByl',
#     'is_local': False,
#     'name': 'Luv Me a Little',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/069369eaa1075368692d474436f6a3b84988912d?cid=11ff7112cf044de8bb8626fb93505bbc',
#     'track_number': 20,
#     'type': 'track',
#     'uri': 'spotify:track:0GJAlocJ1B4N3uFAXXuByl'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5OD01TkUU33QB6NqdrMf3O'},
#        'href': 'https://api.spotify.com/v1/artists/5OD01TkUU33QB6NqdrMf3O',
#        'id': '5OD01TkUU33QB6NqdrMf3O',
#        'name': 'Dylan Joshua',
#        'type': 'artist',
#        'uri': 'spotify:artist:5OD01TkUU33QB6NqdrMf3O'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
# ...
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7pAhzMN0CX1bpuwmDDim0T'},
#       'href': 'https://api.spotify.com/v1/artists/7pAhzMN0CX1bpuwmDDim0T',
#       'id': '7pAhzMN0CX1bpuwmDDim0T',
#       'name': 'Uyen Caddell',
#       'type': 'artist',
#       'uri': 'spotify:artist:7pAhzMN0CX1bpuwmDDim0T'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XC',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 124860,
#     'explicit': False,
#     'external_ids': {'isrc': 'PLH492308445'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1YvUvNLjdynrAOAWGAoMY7'},
#     'href': 'https://api.spotify.com/v1/tracks/1YvUvNLjdynrAOAWGAoMY7',
#     'id': '1YvUvNLjdynrAOAWGAoMY7',
#     'is_local': False,
#     'name': '8 Bit',
#     'popularity': 19,
#     'preview_url': 'https://p.scdn.co/mp3-preview/36ddf37d172ee81da839fabfdd5b8f571567d54d?cid=11ff7112cf044de8bb8626fb93505bbc',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1YvUvNLjdynrAOAWGAoMY7'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0k92GspjcIs5cvvbpMdYz8'},
#        'href': 'https://api.spotify.com/v1/artists/0k92GspjcIs5cvvbpMdYz8',
#        'id': '0k92GspjcIs5cvvbpMdYz8',
#        'name': 'Daxflow',
#        'type': 'artist',
#        'uri': 'spotify:artist:0k92GspjcIs5cvvbpMdYz8'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2zJ5JTsXibFh5qHOdRCeJ9'},
#      'href': 'https://api.spotify.com/v1/albums/2zJ5JTsXibFh5qHOdRCeJ9',
#      'id': '2zJ5JTsXibFh5qHOdRCeJ9',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27338a139895e0b3094cbc349b7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0238a139895e0b3094cbc349b7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485138a139895e0b3094cbc349b7',
#        'width': 64}],
#      'name': 'Instant Messages',
#      'release_date': '2009-08-03',
#      'release_date_precision': 'day',
#      'total_tracks': 22,
#      'type': 'album',
#      'uri': 'spotify:album:2zJ5JTsXibFh5qHOdRCeJ9'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0k92GspjcIs5cvvbpMdYz8'},
#       'href': 'https://api.spotify.com/v1/artists/0k92GspjcIs5cvvbpMdYz8',
#       'id': '0k92GspjcIs5cvvbpMdYz8',
#       'name': 'Daxflow',
#       'type': 'artist',
#       'uri': 'spotify:artist:0k92GspjcIs5cvvbpMdYz8'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XC',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 198948,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZFZ41995386'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1IXJSmaJnCRDWmCIdhLKgH'},
#     'href': 'https://api.spotify.com/v1/tracks/1IXJSmaJnCRDWmCIdhLKgH',
#     'id': '1IXJSmaJnCRDWmCIdhLKgH',
#     'is_local': False,
#     'name': 'A Little Luv',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/40b677776f5ad2885459d4f00d2ae440b4b660e9?cid=11ff7112cf044de8bb8626fb93505bbc',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:1IXJSmaJnCRDWmCIdhLKgH'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Qhv32NzYnQ4YijXdJXTLs'},
#        'href': 'https://api.spotify.com/v1/artists/6Qhv32NzYnQ4YijXdJXTLs',
#        'id': '6Qhv32NzYnQ4YijXdJXTLs',
#        'name': '8 Bit Universe',
#        'type': 'artist',
#        'uri': 'spotify:artist:6Qhv32NzYnQ4YijXdJXTLs'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2xIqDFz4M21hhDRlTqAef0'},
#      'href': 'https://api.spotify.com/v1/albums/2xIqDFz4M21hhDRlTqAef0',
#      'id': '2xIqDFz4M21hhDRlTqAef0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273cfa9c297a1e2e71c80640b1e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02cfa9c297a1e2e71c80640b1e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851cfa9c297a1e2e71c80640b1e',
#        'width': 64}],
#      'name': '8 Bit Jawns',
#      'release_date': '2016-01-29',
#      'release_date_precision': 'day',
#      'total_tracks': 29,
#      'type': 'album',
#      'uri': 'spotify:album:2xIqDFz4M21hhDRlTqAef0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Qhv32NzYnQ4YijXdJXTLs'},
#       'href': 'https://api.spotify.com/v1/artists/6Qhv32NzYnQ4YijXdJXTLs',
#       'id': '6Qhv32NzYnQ4YijXdJXTLs',
#       'name': '8 Bit Universe',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Qhv32NzYnQ4YijXdJXTLs'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 225534,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCACL1631720'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/77PhhruRvyonqhzwKEYHU8'},
#     'href': 'https://api.spotify.com/v1/tracks/77PhhruRvyonqhzwKEYHU8',
#     'id': '77PhhruRvyonqhzwKEYHU8',
#     'is_local': False,
#     'name': 'Sandstorm (8 Bit Version)',
#     'popularity': 18,
#     'preview_url': 'https://p.scdn.co/mp3-preview/74d0b4e44a3bdffbb368c1f1c472bbd56584286e?cid=11ff7112cf044de8bb8626fb93505bbc',
#     'track_number': 15,
#     'type': 'track',
#     'uri': 'spotify:track:77PhhruRvyonqhzwKEYHU8'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=Luv+me+a+little+NOT+8-Bit&type=track&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 1000}}

# %%
track_id = spotify.search(query = "Luv me a little", search_type="track")
print(track_id)
# Out:
# q=Luv+me+a+little&type=track
# https://api.spotify.com/v1/search?q=Luv+me+a+little&type=track
# 200
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Luv+me+a+little&type=track&offset=0&limit=20', 'items': [{'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/45eNHdiiabvmbp4erw26rg'}, 'href': 'https://api.spotify.com/v1/artists/45eNHdiiabvmbp4erw26rg', 'id': '45eNHdiiabvmbp4erw26rg', 'name': 'ILLENIUM', 'type': 'artist', 'uri': 'spotify:artist:45eNHdiiabvmbp4erw26rg'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/7AzjETXRUKNRSJHMW9GIqd'}, 'href': 'https://api.spotify.com/v1/artists/7AzjETXRUKNRSJHMW9GIqd', 'id': '7AzjETXRUKNRSJHMW9GIqd', 'name': 'Nina Nesbitt', 'type': 'artist', 'uri': 'spotify:artist:7AzjETXRUKNRSJHMW9GIqd'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BZ', 'CA', 'CD', 'CG', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'ET', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IQ', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'KZ', 'LA', 'LB', 'LC', 'LI', 'LK', 'LR', 'LS', 'LT', 'LU', 'LV', 'LY', 'MA', 'MC', 'MD', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PK', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TJ', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'UG', 'US', 'UY', 'UZ', 'VC', 'VE', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'external_urls': {'spotify': 'https://open.spotify.com/album/7rZOkDS1qDISQN3kValLId'}, 'href': 'https://api.spotify.com/v1/albums/7rZOkDS1qDISQN3kValLId', 'id': '7rZOkDS1qDISQN3kValLId', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2732c63e6bc06a8b23366662cd5', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e022c63e6bc06a8b23366662cd5', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d000048512c63e6bc06a8b23366662cd5', 'width': 64}], 'name': 'Luv Me A Little', 'release_date': '2023-01-20', 'release_date_precision': 'day', 'total_tracks': 1, 'type': 'album', 'uri': 'spotify:album:7rZOkDS1qDISQN3kValLId'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/45eNHdiiabvmbp4erw26rg'}, 'href': 'https://api.spotify.com/v1/artists/45eNHdiiabvmbp4erw26rg', 'id': '45eNHdiiabvmbp4erw26rg', 'name': 'ILLENIUM', 'type': 'artist', 'uri': 'spotify:artist:45eNHdiiabvmbp4erw26rg'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/7AzjETXRUKNRSJHMW9GIqd'}, 'href': 'https://api.spotify.com/v1/artists/7AzjETXRUKNRSJHMW9GIqd', 'id': '7AzjETXRUKNRSJHMW9GIqd', 'name': 'Nina Nesbitt', 'type': 'artist', 'uri': 'spotify:artist:7AzjETXRUKNRSJHMW9GIqd'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU ...
